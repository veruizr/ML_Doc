# %% [markdown]
# <a href="https://colab.research.google.com/github/veruizr/ML_Doc/blob/main/rimas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reto ML 13/02

# %%
#Realice una función rima que encuentre las palabras que finalizan según el parámetro
def rima(final):
  palabras_rima=[]
  final=final+'\n'
  archivo  = open('5000_palabras_comunes.txt', encoding="utf-8")
  lineas = archivo.readlines()
  archivo.close()

  for linea in lineas:
    if linea.endswith(final):
      palabras_rima.append(linea[:-1])

  print(len(palabras_rima))
  #print(palabras_rima)
  if len(palabras_rima)==0:
    print('No hay coincidencias')

  return(palabras_rima)

# %%
final='ten'
rima(final)
# Out:
# 5
# ['ten', 'existen', 'maten', 'sienten', 'corten']

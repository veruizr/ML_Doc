# %% [markdown]
# <a href="https://colab.research.google.com/github/veruizr/ML_Doc/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
#
# Matplotlib es una biblioteca de Python utilizada para crear visualizaciones estáticas, animadas e interactivas. Es especialmente útil para representar gráficos de diversas funciones y datos tanto en 2D como en 3D.
#
# Para instalar Matplotlib:

# %%
#pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráficos de Líneas

# %%
#import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 10, 100)
y = np.sin(2*x+1)

plt.plot(x, y, label='Sin(2x+1)')
plt.title('')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %% [markdown]
# ## Gráficos de barras

# %%
categorias = ['A', 'B', 'C', 'D']
valores = [10, 20, 15, 25]

plt.bar(categorias, valores)
plt.title('Gráfico de Barras')
plt.show()

# %% [markdown]
# ### Gráfico de Dispersión

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y)
plt.title('Gráfico de Dispersión')
plt.show()

# %% [markdown]
# ### Gráfico en 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

ax.plot_surface(x, y, z, cmap='viridis')
plt.title('Superficie 3D')
plt.show()
